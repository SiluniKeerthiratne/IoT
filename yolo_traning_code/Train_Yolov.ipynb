# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.0/950.0 kB 25.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 57.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 19.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 36.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 71.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# Install the required packages for YOLO11 and Comet ML
# !pip install comet_ml torch torchvision
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 726.0/726.0 kB 21.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 52.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 98.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: python-box
#     Found existing installation: python-box 7.3.2
#     Uninstalling python-box-7.3.2:
#       Successfully uninstalled python-box-7.3.2
# ...

# %%
# Set your Comet Api Key
# !export COMET_API_KEY=yXlWWyyCIWIDRmLjpEWU871FF

# %%
import comet_ml

comet_ml.login(project_name="IoT")

# %%
import zipfile
import requests
import cv2
import matplotlib.pyplot as plt
import glob
import random
import os

# %%
# %cd ..
# Out:
# /

# %%
# %cd content/
# Out:
# /content

# %%
os.makedirs('datasets', exist_ok=True)

# %%
import zipfile
import os

def unzip(zip_file=None, extract_to="./extracted"):
    try:
        # Create the target folder if it does not exist
        if not os.path.exists(extract_to):
            os.makedirs(extract_to)

        # Extract all files to the specified folder
        with zipfile.ZipFile(zip_file, 'r') as z:
            z.extractall(extract_to)
            print(f"Extracted all to {extract_to}")
    except Exception as e:
        print(f"An error occurred: {e}")

# Call the function, passing the zip file path and folder to extract into
unzip('/content/drive/MyDrive/Siluni_Docs/MyData_1_split.zip', '../content/datasets')
# Out:
# Extracted all to ../content/datasets

# %%
import shutil

# Copy file
shutil.copy('/content/drive/MyDrive/Siluni_Docs/data.yaml', '../content/datasets')
# Out:
# '../content/datasets/data.yaml'

# %%
# %cd ..
# Out:
# /

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov9t.pt")  # load a pretrained model (recommended for training)


# Train the model
results = model.train(
    data="../content/datasets/data.yaml",
    epochs=10,
    imgsz=640,
    batch=8,
    project="IoT",
    save_period=1,
    save_json=True,
)
# Out:
# ...
# 100%|██████████| 4.74M/4.74M [00:00<00:00, 83.6MB/s]
# Ultralytics 8.3.98 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map  # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps  # a list contains map50-95 of each category
# Out:
# WARNING ⚠️ validating an untrained model YAML will result in 0 mAP.
# Ultralytics 8.3.13 🚀 Python-3.10.12 torch-2.4.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLO11n summary (fused): 238 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /content/datasets/valid/labels.cache... 123 images, 0 backgrounds, 0 corrupt: 100%|██████████| 123/123 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:34<00:00,  4.32s/it]
#                    all        123       2877      0.802      0.245       0.26      0.158
#                   ball         84         84          1          0          0          0
#            goal keeper         88         94          1          0     0.0274     0.0153
#                 player        123       2425      0.743      0.934      0.881      0.536
#                 refree        123        274      0.464     0.0438       0.13     0.0788
# ...
